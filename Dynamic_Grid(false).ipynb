# %% [markdown]
# <a href="https://colab.research.google.com/github/princekrsingh780-gif/DMAV-lab/blob/main/Dynamic_Grid(false).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Taking input from user
x = list(map(int, input("Enter X values (space-separated): ").split()))
y = list(map(int, input("Enter Y values (space-separated): ").split()))

# Check if lengths match
if len(x) != len(y):
    print("Error: X & Y must have same number of values")
else:
    plt.plot(x, y, marker='o')

    plt.grid(False)

    plt.xlabel("X values")
    plt.ylabel("Y values")
    plt.title("Graph without Grid")

    plt.show()
# Out:
# Enter X values (space-separated): 1 2 3 4 5
# Enter Y values (space-separated): 10 20 25 30 35
